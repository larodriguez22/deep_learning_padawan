# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from huggingface_hub import login
login()

# %%
import wandb
wandb.login()
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/adega/.netrc.
# wandb: Currently logged in as: la-rodriguez (la-rodriguez-universidad-de-los-andes) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
raw_dataset_path = 'spa_guc_dataset.csv'

# %%
# Load the CSV file
df = pd.read_csv(raw_dataset_path, sep='|')

# Create the 'id' column
df['id'] = df.index

# Create the 'translation' column
df['translation'] = df[['spa', 'guc']].apply(lambda row: {"spa": row['spa'], "guc": row['guc']}, axis=1)

translation_df = df[['id', 'translation']]

# %%
translation_spa_pbb_train, translation_spa_pbb_test = train_test_split(translation_df, test_size=0.2, random_state=42)
translation_spa_pbb_train, translation_spa_pbb_val = train_test_split(translation_spa_pbb_train, test_size=0.2, random_state=42)

#%%
translation_spa_pbb_train.reset_index(drop=True, inplace=True)
translation_spa_pbb_val.reset_index(drop=True, inplace=True)
translation_spa_pbb_test.reset_index(drop=True, inplace=True)

# %%
from datasets import Dataset, DatasetDict

dataset = DatasetDict(
    {
        "train": Dataset.from_pandas(translation_spa_pbb_train),
        "validation": Dataset.from_pandas(translation_spa_pbb_val),
        "test": Dataset.from_pandas(translation_spa_pbb_test),
    }
)

# %%
dataset.push_to_hub("translation_spa_guc")
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ? shards/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ? shards/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ? shards/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# CommitInfo(commit_url='https://huggingface.co/datasets/lrodriguez22/translation_spa_guc/commit/4f8d181376e34081468f25ce1bce5ccad70bc26f', commit_message='Upload dataset', commit_description='', oid='4f8d181376e34081468f25ce1bce5ccad70bc26f', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/lrodriguez22/translation_spa_guc', endpoint='https://huggingface.co', repo_type='dataset', repo_id='lrodriguez22/translation_spa_guc'), pr_revision=None, pr_num=None)
